# %%
# Import the random module.
import random

# %%
random.randint(-90, 90)
# Out:
# 15

# %%
random.random()
# Out:
# 0.5011750450600087

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# 1.8096756669595464

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=3)
# Out:
# -24

# %%
random.uniform(-90, 90)
# Out:
# -83.6617993623809

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 8.116740723074344

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ -1.41203789,  56.14143727,  11.33407729,  79.56029486,
#        -83.35265393,  16.82822647, -33.96051218,  36.23265144,
#         35.336571  ,  69.62913751, -84.35676157,  80.33014585,
#        -24.51563341,  83.83632943, -21.64013946, -55.81281785,
#         18.44957543, -83.31465935, -85.76205499, -80.67939872,
#        -73.73862689,  -0.5787145 , -33.26123915,  84.84222336,
#         50.01903168, -52.88657144,  19.59445511, -86.37766127,
#         36.18241568,  45.96106564,  25.63816384,  80.29422722,
#         46.23824653,  -2.57066239,   2.29550708,  -4.44311926,
#        -28.81827525,  -0.9800612 , -16.98170022, -82.90686373,
#        -73.16571001,  85.25948741,  89.7152191 , -14.06570437,
#          7.43991477, -87.03890256,  31.12519891, -45.99307884,
#        -51.61170342,  56.89677312])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 17.4 µs ± 640 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 2.36 ms ± 317 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
